# %%
import pandas as pd
'''
https://bigdata.kepco.co.kr/cmsmain.do?scode=S01&pcode=000170
전국 전기차 충전소 설치 현황
'''
df = pd.read_excel('Electric.xls')
df
# Out:
#           전기차 충전소 설치현황 ( 20210624 현재 )  Unnamed: 1                 Unnamed: 2  \
# 0     시도 : 전체(시도), 시군구 : 전체(시 / 군 / 구)         NaN                        NaN
# 1                                   시구        설치장소                         주소
# 2                                   전체     가평종합운동장                          -
# 3                                   전체        가평지사     경기도 가평군 가평읍 가화로 169-11
# 4                                   전체    가평하수도사업소        경기도 가평군 가평읍 달전리 364
# ...                                ...         ...                        ...
# 3953                                전체     화정글샘도서관          경상남도 김해시 삼계동 1437
# 3954                                전체      화천민원센터  경상남도 창원시 의창구 북면 천주로 483-7
# 3955                                전체  황성동 행정복지센터           경상북도 경주시 황성동 167
# 3956                                전체  휴먼빌2단지 아파트     경상남도 창원시 의창구 북면 동곡로 35
# 3957                                전체        휴플러스        전라북도 진안군 진안읍 진용로 64
#
# ...

# %%
df.to_csv('Electric.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3959 entries, 0 to 3958
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       3958 non-null   float64
#  1   1       3959 non-null   object
#  2   2       3958 non-null   object
#  3   3       3958 non-null   object
#  4   4       3958 non-null   object
#  5   5       3958 non-null   object
#  6   6       3958 non-null   object
# dtypes: float64(1), object(6)
# memory usage: 216.6+ KB

# %% [markdown]
# ## - 지역별 전기차 이용순위

# %%
df = pd.read_csv('Electric.csv', header = None)
df
# Out:
#            0                                 1           2  \
# 0        NaN      전기차 충전소 설치현황 ( 20210624 현재 )  Unnamed: 1
# 1        0.0  시도 : 전체(시도), 시군구 : 전체(시 / 군 / 구)         NaN
# 2        1.0                                시구        설치장소
# 3        2.0                                전체     가평종합운동장
# 4        3.0                                전체        가평지사
# ...      ...                               ...         ...
# 3954  3953.0                                전체     화정글샘도서관
# 3955  3954.0                                전체      화천민원센터
# 3956  3955.0                                전체  황성동 행정복지센터
# 3957  3956.0                                전체  휴먼빌2단지 아파트
# 3958  3957.0                                전체        휴플러스
#
#                               3           4           5  \
# 0                    Unnamed: 2  Unnamed: 3  Unnamed: 4
# 1                           NaN         NaN         NaN
# 2                            주소    급속충전기(대)    완속충전기(대)
# ...

# %%
df1 = df.rename(columns=df.iloc[2])
df1
# Out:
#          1.0                                시구        설치장소  \
# 0        NaN      전기차 충전소 설치현황 ( 20210624 현재 )  Unnamed: 1
# 1        0.0  시도 : 전체(시도), 시군구 : 전체(시 / 군 / 구)         NaN
# 2        1.0                                시구        설치장소
# 3        2.0                                전체     가평종합운동장
# 4        3.0                                전체        가평지사
# ...      ...                               ...         ...
# 3954  3953.0                                전체     화정글샘도서관
# 3955  3954.0                                전체      화천민원센터
# 3956  3955.0                                전체  황성동 행정복지센터
# 3957  3956.0                                전체  휴먼빌2단지 아파트
# 3958  3957.0                                전체        휴플러스
#
#                              주소    급속충전기(대)    완속충전기(대)  \
# 0                    Unnamed: 2  Unnamed: 3  Unnamed: 4
# 1                           NaN         NaN         NaN
# 2                            주소    급속충전기(대)    완속충전기(대)
# ...

# %%
df1[['설치장소','지원차종']]
# Out:
#             설치장소                                               지원차종
# 0     Unnamed: 1                                         Unnamed: 5
# 1            NaN                                                NaN
# 2           설치장소                                               지원차종
# 3        가평종합운동장                                        SM3 Z.E,테슬라
# 4           가평지사  SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트E...
# ...          ...                                                ...
# 3954     화정글샘도서관  SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트E...
# 3955      화천민원센터  SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트E...
# 3956  황성동 행정복지센터                                        SM3 Z.E,테슬라
# 3957  휴먼빌2단지 아파트  SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트E...
# 3958        휴플러스            레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV
#
# [3959 rows x 2 columns]

# %%
result = df1['지원차종'].unique()
result
# Out:
# array(['Unnamed: 5', nan, '지원차종', 'SM3 Z.E,테슬라',
#        'SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라',
#        '레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV', 'BMW i3,스파크EV,볼트EV',
#        ' ', 'SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,테슬라',
#        '레이EV,소울EV,닛산리프,아이오닉EV,BMW i3'], dtype=object)

# %%
result[0].split(',')
# Out:
# ['Unnamed: 5']

# %%
pd.Series.value_counts(result)
# Out:
#                                                        1
# 지원차종                                                   1
# SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,테슬라               1
# 레이EV,소울EV,닛산리프,아이오닉EV,BMW i3                           1
# 레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV                1
# Unnamed: 5                                             1
# SM3 Z.E,레이EV,소울EV,닛산리프,아이오닉EV,BMW i3,스파크EV,볼트EV,테슬라    1
# SM3 Z.E,테슬라                                            1
# BMW i3,스파크EV,볼트EV                                      1
# dtype: int64

# %% [markdown]
# ##  - 지역별 전기차 충전소 설치량(급속 / 완속) 순위
